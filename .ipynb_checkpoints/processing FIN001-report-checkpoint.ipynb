# %%
import pandas as pd

# %% [markdown]
# <h4>Read FIN001 sample report and paycheck table</h4>

# %%
FIN001filepath = r"C:\Users\awidjaja\Documents\RFL- POC\Input_Files\UC_FIN001_PAYCHECK_DEDUCTIONS_774084231.xls"
df = pd.read_excel(FIN001filepath, header=1)
paycheckfilepath=r"C:\Users\awidjaja\Documents\RFL- POC\Input_Files\PYCK DATES_V2.xlsx"
dfPaycheck = pd.read_excel(paycheckfilepath,sheet_name='cleaned')

# %%
df['Payback Amount'][0] = 3
df['Refund Amount'][10] = 33.5
df['Not Taken'][11] = 270
df['Not Taken'][12] = -250
df['Reason'][12] = "Some random reasons..."
df['Paycheck Status'][13] = "NOT CONFIRMED"
df['Paycheck Option'][13] = "Not Advice"
df['Off Cycle'][20] ='Y'

# %% [markdown]
# <h4>Highlight variances on Payback Amount, Refund Amount, Not Taken, Reason , Paycheck Status , Paycheck Option, OffCycle</h4>
# <p>Conditions are as follow:</p>
# <ul>
#     <li>if Payback Amount > 0.00, then color cell </li>
#     <li>if Refund Amount > 0.00, then color cell </li>
#     <li>if Not Taken > 0.00, then color cell </li>
#     <li>if Reason != null, then color cell </li>
#     <li>if Paycheck Status != 'Confirmed', then color cell </li>
#     <li>if Paycheck Options != 'Advice', then color cell </li>
#     <li>if Off Cycle != 'N'</li>
# </ul>

# %%
df['Reason'].fillna("Null",inplace=True)

# %% [markdown]
# <p>Note about Styler object:</p>
# <ol>
# <li>When you call df.style, it returns a pandas.io.formats.style.Styler object, not a DataFrame.</li>
# <li>The Styler object provides methods for applying various styles (e.g., highlighting, formatting, coloring) to the DataFrame's display.</li>
# <li>It is not intended for data selection or modification, which are operations performed on the underlying DataFrame itself.</li>
# </ol>
#     <p>Solution: To resolve this error, ensure that you are performing data selection or manipulation on the original DataFrame before applying styling, or access the underlying DataFrame data from the Styler object if necessary.</p>
#     <p>In summary, the Styler object is for presentation and not for data manipulation using subscripting. Always ensure you are interacting with the appropriate object (DataFrame for data, Styler for styling) for the intended operation.</p>

# %%
def highlightAnomalies(val, col_name):
    if col_name == 'Payback Amount' and (val >0 or val <0):
        return 'background-color: pink'
    elif col_name =='Refund Amount' and (val > 0 or val<0):
        return 'background-color:pink'
    elif col_name =='Not Taken' and (val > 0 or val<0):
        return 'background-color:pink'
    elif col_name == 'Reason' and val != "Null":
        return 'background-color:pink'
    elif col_name =='Paycheck Status' and val !="Confirmed":
        return 'background-color:pink'
    elif col_name =='Paycheck Option' and val !="Advice":
        return 'background-color:pink'
    elif col_name =='Off Cycle' and val !="N":
        return 'background-color:pink'
    else:
        return ''
    

dfStyler = df.style.applymap(lambda x: highlightAnomalies(x, 'Payback Amount'), subset=['Payback Amount'])\
.applymap(lambda x: highlightAnomalies(x, 'Refund Amount'), subset=['Refund Amount'])\
.applymap(lambda x: highlightAnomalies(x, 'Not Taken'), subset=['Not Taken'])\
.applymap(lambda x: highlightAnomalies(x, 'Reason'), subset=['Reason'])\
.applymap(lambda x: highlightAnomalies(x, 'Paycheck Status'), subset=['Paycheck Status'])\
.applymap(lambda x: highlightAnomalies(x, 'Paycheck Option'), subset=['Paycheck Option'])\
.applymap(lambda x: highlightAnomalies(x, 'Off Cycle'), subset=['Off Cycle'])

# %%
dfStyler
# Out:
# <style type="text/css">
# #T_ef92f_row0_col14, #T_ef92f_row10_col15, #T_ef92f_row11_col16, #T_ef92f_row12_col16, #T_ef92f_row12_col17, #T_ef92f_row13_col19, #T_ef92f_row13_col20, #T_ef92f_row20_col21, #T_ef92f_row150_col19, #T_ef92f_row150_col20, #T_ef92f_row150_col21 {
#   background-color: pink;
# }
# </style>
# <table id="T_ef92f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ef92f_level0_col0" class="col_heading level0 col0" >Business Unit</th>
#       <th id="T_ef92f_level0_col1" class="col_heading level0 col1" >Employee ID</th>
#       <th id="T_ef92f_level0_col2" class="col_heading level0 col2" >Employee Record</th>
#       <th id="T_ef92f_level0_col3" class="col_heading level0 col3" >Employee Name</th>
#       <th id="T_ef92f_level0_col4" class="col_heading level0 col4" >Pay Group</th>
#       <th id="T_ef92f_level0_col5" class="col_heading level0 col5" >Pay Period End Date</th>
#       <th id="T_ef92f_level0_col6" class="col_heading level0 col6" >Paycheck Issue Date</th>
#       <th id="T_ef92f_level0_col7" class="col_heading level0 col7" >Employee Type</th>
#       <th id="T_ef92f_level0_col8" class="col_heading level0 col8" >Plan Type</th>
#       <th id="T_ef92f_level0_col9" class="col_heading level0 col9" >Benefit Plan</th>
#       <th id="T_ef92f_level0_col10" class="col_heading level0 col10" >Deduction Code</th>
#       <th id="T_ef92f_level0_col11" class="col_heading level0 col11" >Deduction Code Descr</th>
#       <th id="T_ef92f_level0_col12" class="col_heading level0 col12" >Deduction Classification</th>
#       <th id="T_ef92f_level0_col13" class="col_heading level0 col13" >Current Deduction</th>
#       <th id="T_ef92f_level0_col14" class="col_heading level0 col14" >Payback Amount</th>
#       <th id="T_ef92f_level0_col15" class="col_heading level0 col15" >Refund Amount</th>
#       <th id="T_ef92f_level0_col16" class="col_heading level0 col16" >Not Taken</th>
#       <th id="T_ef92f_level0_col17" class="col_heading level0 col17" >Reason</th>
#       <th id="T_ef92f_level0_col18" class="col_heading level0 col18" >Calculated Base</th>
#       <th id="T_ef92f_level0_col19" class="col_heading level0 col19" >Paycheck Status</th>
#       <th id="T_ef92f_level0_col20" class="col_heading level0 col20" >Paycheck Option</th>
#       <th id="T_ef92f_level0_col21" class="col_heading level0 col21" >Off Cycle</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ef92f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ef92f_row0_col0" class="data row0 col0" >IRMED</td>
#       <td id="T_ef92f_row0_col1" class="data row0 col1" >10720905</td>
#       <td id="T_ef92f_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_ef92f_row0_col3" class="data row0 col3" >Araiza,Yuanyi</td>
#       <td id="T_ef92f_row0_col4" class="data row0 col4" >IB7</td>
#       <td id="T_ef92f_row0_col5" class="data row0 col5" >2024-03-30 00:00:00</td>
#       <td id="T_ef92f_row0_col6" class="data row0 col6" >2024-04-10 00:00:00</td>
#       <td id="T_ef92f_row0_col7" class="data row0 col7" >Hourly</td>
#       <td id="T_ef92f_row0_col8" class="data row0 col8" >Life</td>
#       <td id="T_ef92f_row0_col9" class="data row0 col9" >BLIF</td>
#       <td id="T_ef92f_row0_col10" class="data row0 col10" >BLIF</td>
#       <td id="T_ef92f_row0_col11" class="data row0 col11" >Basic Life</td>
#       <td id="T_ef92f_row0_col12" class="data row0 col12" >Nontaxable Benefit</td>
#       <td id="T_ef92f_row0_col13" class="data row0 col13" >3.920000</td>
#       <td id="T_ef92f_row0_col14" class="data row0 col14" >3</td>
#       <td id="T_ef92f_row0_col15" class="data row0 col15" >0.000000</td>
#       <td id="T_ef92f_row0_col16" class="data row0 col16" >0</td>
#       <td id="T_ef92f_row0_col17" class="data row0 col17" >Null</td>
#       <td id="T_ef92f_row0_col18" class="data row0 col18" >50000.000000</td>
#       <td id="T_ef92f_row0_col19" class="data row0 col19" >Confirmed</td>
#       <td id="T_ef92f_row0_col20" class="data row0 col20" >Advice</td>
#       <td id="T_ef92f_row0_col21" class="data row0 col21" >N</td>
#     </tr>
#     <tr>
#       <th id="T_ef92f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ef92f_row1_col0" class="data row1 col0" >IRMED</td>
#       <td id="T_ef92f_row1_col1" class="data row1 col1" >10720905</td>
#       <td id="T_ef92f_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_ef92f_row1_col3" class="data row1 col3" >Araiza,Yuanyi</td>
#       <td id="T_ef92f_row1_col4" class="data row1 col4" >IB7</td>
#       <td id="T_ef92f_row1_col5" class="data row1 col5" >2024-03-30 00:00:00</td>
#       <td id="T_ef92f_row1_col6" class="data row1 col6" >2024-04-10 00:00:00</td>
#       <td id="T_ef92f_row1_col7" class="data row1 col7" >Hourly</td>
#       <td id="T_ef92f_row1_col8" class="data row1 col8" >UC Retirement Plan</td>
#       <td id="T_ef92f_row1_col9" class="data row1 col9" >T13DHX</td>
#       <td id="T_ef92f_row1_col10" class="data row1 col10" >UCRPBT</td>
#       <td id="T_ef92f_row1_col11" class="data row1 col11" >UC Retirement Plan</td>
#       <td id="T_ef92f_row1_col12" class="data row1 col12" >Before-Tax</td>
#       <td id="T_ef92f_row1_col13" class="data row1 col13" >85.160000</td>
#       <td id="T_ef92f_row1_col14" class="data row1 col14" >0</td>
#       <td id="T_ef92f_row1_col15" class="data row1 col15" >0.000000</td>
#       <td id="T_ef92f_row1_col16" class="data row1 col16" >0</td>
#       <td id="T_ef92f_row1_col17" class="data row1 col17" >Null</td>
#       <td id="T_ef92f_row1_col18" class="data row1 col18" >0.000000</td>
#       <td id="T_ef92f_row1_col19" class="data row1 col19" >Confirmed</td>
#       <td id="T_ef92f_row1_col20" class="data row1 col20" >Advice</td>
#       <td id="T_ef92f_row1_col21" class="data row1 col21" >N</td>
#     </tr>
#     <tr>
#       <th id="T_ef92f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ef92f_row2_col0" class="data row2 col0" >IRMED</td>
#       <td id="T_ef92f_row2_col1" class="data row2 col1" >10720905</td>
#       <td id="T_ef92f_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_ef92f_row2_col3" class="data row2 col3" >Araiza,Yuanyi</td>
#       <td id="T_ef92f_row2_col4" class="data row2 col4" >IB7</td>
#       <td id="T_ef92f_row2_col5" class="data row2 col5" >2024-03-30 00:00:00</td>
#       <td id="T_ef92f_row2_col6" class="data row2 col6" >2024-04-10 00:00:00</td>
#       <td id="T_ef92f_row2_col7" class="data row2 col7" >Hourly</td>
#       <td id="T_ef92f_row2_col8" class="data row2 col8" >UC Retirement Plan</td>
#       <td id="T_ef92f_row2_col9" class="data row2 col9" >T13DHX</td>
#       <td id="T_ef92f_row2_col10" class="data row2 col10" >UCRPBT</td>
#       <td id="T_ef92f_row2_col11" class="data row2 col11" >UC Retirement Plan</td>
#       <td id="T_ef92f_row2_col12" class="data row2 col12" >Nontaxable Benefit</td>
#       <td id="T_ef92f_row2_col13" class="data row2 col13" >132.480000</td>
#       <td id="T_ef92f_row2_col14" class="data row2 col14" >0</td>
#       <td id="T_ef92f_row2_col15" class="data row2 col15" >0.000000</td>
#       <td id="T_ef92f_row2_col16" class="data row2 col16" >0</td>
#       <td id="T_ef92f_row2_col17" class="data row2 col17" >Null</td>
#       <td id="T_ef92f_row2_col18" class="data row2 col18" >0.000000</td>
#       <td id="T_ef92f_row2_col19" class="data row2 col19" >Confirmed</td>
#       <td id="T_ef92f_row2_col20" class="data row2 col20" >Advice</td>
#       <td id="T_ef92f_row2_col21" class="data row2 col21" >N</td>
#     </tr>
#     <tr>
#       <th id="T_ef92f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ef92f_row3_col0" class="data row3 col0" >IRMED</td>
#       <td id="T_ef92f_row3_col1" class="data row3 col1" >10720905</td>
#       <td id="T_ef92f_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_ef92f_row3_col3" class="data row3 col3" >Araiza,Yuanyi</td>
#       <td id="T_ef92f_row3_col4" class="data row3 col4" >IB7</td>
#       <td id="T_ef92f_row3_col5" class="data row3 col5" >2024-04-13 00:00:00</td>
#       <td id="T_ef92f_row3_col6" class="data row3 col6" >2024-04-24 0

# %% [markdown]
# <h4>Split dataframe by plan type</h4>

# %%
plantype_dfs={}

# %%
for plan, planDF in df.groupby(by=['Plan Type']):
    plantype_dfs[plan] = planDF

# %%
plantype_dfs.keys()
# Out:
# dict_keys(['403(b)', 'Basic Disability', 'Dental', 'Employee & Dependent AD&D', 'Exp Dependent Life - Spouse/DP', 'Health Savings Account', 'Legal Insurance', 'Life', 'Medical', 'Supplemental Life', 'UC Retirement Plan', 'Vision', 'Voluntary LongTerm Disability', 'Voluntary ShortTerm Disability'])

# %%
plantype_dfs['403(b)']['Paycheck Issue Date']
# Out:
# 14    2024-05-08
# 31    2024-05-22
# 47    2024-06-05
# 63    2024-06-18
# 75    2024-07-03
# 91    2024-07-17
# 103   2024-07-31
# 106   2024-08-14
# 122   2024-08-28
# 134   2024-09-11
# Name: Paycheck Issue Date, dtype: datetime64[ns]

# %%
plantype_dfs['Basic Disability']['Paycheck Issue Date']
# Out:
# 15    2024-05-08
# 32    2024-05-22
# 48    2024-06-05
# 76    2024-07-03
# 107   2024-08-14
# 135   2024-09-11
# Name: Paycheck Issue Date, dtype: datetime64[ns]

# %% [markdown]
# <h4>Identifying missed paycheck dates </h4>

# %%
minDate = plantype_dfs['403(b)']['Paycheck Issue Date'].min().strftime("%Y-%m-%d")
maxDate = plantype_dfs['403(b)']['Paycheck Issue Date'].max().strftime("%Y-%m-%d")

print(minDate)
print(maxDate)

# %%
dfPaycheck[2024][(dfPaycheck[2024]>= minDate)& (dfPaycheck[2024] <=maxDate)]
